# %%
from selenium import webdriver
import time

# %%
import pandas as pd
driver_path='C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe'
browser=webdriver.Chrome(driver_path)

car1_url='https://www.araba.com/ilan/mercedes-benz-c-220-cdi-avantgarde-otomatik-full-full-1885379'

browser.get(car1_url)


content = browser.find_elements_by_css_selector('div.car-detail-container')

contlist=[]
for i in content:
    a=i.text
    contlist=a.split("\n")
contlist[::2]
# Out:
# ['174.999 TL',
#  'ARABA DEĞERİ HESAPLA',
#  '/ Merkez / Merkez',
#  '#1885379',
#  '20/03/2021',
#  'Mercedes',
#  'C',
#  '220 CDI Avantgarde',
#  '2003',
#  '279.000',
#  'Dizel',
#  'Otomatik Vites',
#  '2001-2500 cc',
#  '126-150 BG',
#  'Galeriden']

# %%
    
# List1  
lst = [   [ contlist[3],contlist[6],contlist[8],contlist[10],contlist[12],contlist[14],contlist[16],contlist[18],contlist[20],contlist[22],contlist[24],contlist[26],contlist[28],contlist[0]  ]   ] 
    
df = pd.DataFrame(lst,columns=['city','advertisement_number', 'advertisement_date','brand','model','version','year','km','fuel','gear','engine_capacity','engine_power','from','price']) 
df
# Out:
#        city advertisement_number advertisement_date     brand model  \
# 0  Nevşehir             #1885379         20/03/2021  Mercedes     C
#
#               version  year       km   fuel            gear engine_capacity  \
# 0  220 CDI Avantgarde  2003  279.000  Dizel  Otomatik Vites    2001-2500 cc
#
#   engine_power       from       price
# 0   126-150 BG  Galeriden  174.999 TL

# %%
content[0].text[0:10]
# Out:
# '174.999 TL'

# %%
driver_path='C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe'
browser=webdriver.Chrome(driver_path)
browser.get('https://www.araba.com/otomobil/mercedes')


//*[@id="park_or_compare"]/table/tbody/tr[1]

//*[@id="park_or_compare"]/table/tbody/tr[2]

//*[@id="park_or_compare"]/table/tbody/tr[22]

# %%
driver_path='C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe'
browser=webdriver.Chrome(driver_path)

car1_url='https://www.sahibinden.com/ilan/vasita-otomobil-mercedes-benz-c180-amg-2014-model-97000-km-hatasiz-boyasiz-tramersiz-915559307/detay'

browser.get(car1_url)

content = browser.find_elements_by_css_selector('div.classifiedInfo ')
baslik=browser.find_elements_by_css_selector('div.classifiedDetailTitle')
contlist1=[]
contlist2=[]
for i in content:
    a=i.text
    contlist1=a.split("\n")
for i in baslik:
    a=i.text
    contlist2=a.split("\n")
    
contlist=contlist1+contlist2
contlist[:]
# Out:
# ['373.000 TL',
#  'Ankara / Çankaya / Oran Mah.',
#  'İlan No',
#  '  915559307',
#  'İlan Tarihi',
#  '  21 Mart 2021',
#  'Marka',
#  '  Mercedes - Benz ',
#  'Seri',
#  '  C Serisi ',
#  'Model',
#  '  C 180 AMG 7G-Tronic ',
#  'Yıl',
#  '  2014',
#  'Yakıt',
#  '  Benzin',
#  'Vites',
#  '  Otomatik',
#  'KM',
#  '  97.000',
#  'Kasa Tipi',
#  '  Sedan',
#  'Motor Gücü',
#  '  156 hp',
#  'Motor Hacmi',
#  '  1595 cc',
#  'Çekiş',
#  '  Arkadan İtiş',
#  'Renk',
#  '  Gri',
#  'Garanti',
#  '  Hayır',
#  'Plaka / Uyruk',
#  '  Türkiye (TR) Plakalı',
#  'Kimden',
#  '  Sahibinden',
#  'Görüntülü Arama İle Görülebilir',
#  '  Hayır',
#  'Takas',
#  '  Hayır ',
#  'Durumu',
#  '  İkinci El ',
#  'İlan ile İlgili Şikayetim Var',
#  'C180 AMG 2014 Model 97000 KM HATASİZ BOYASIZ TRAMERSİZ',
#  'Favorilerime Ekle',
#  '',
#  '',
#  'Yazdır',
#  'Facebook ile paylaş Twitter ile paylaş E-posta ile gönder']

# %%
driver_path='C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe'
browser=webdriver.Chrome(driver_path)

car1_url='https://www.arabam.com/ilan/galeriden-satilik-mercedes-benz-e-300-amg/levent-motors-2017-mercedes-e-300-coupe-command-hayalet-nvg-vkm/17188504'

browser.get(car1_url)

content=browser.find_elements_by_xpath('//*[@id="wrapper"]/div[6]/div[3]/div/div[1]')

#content
contlist=[]
for i in content:
    a=i.text
    contlist=a.split("\n")
contlist[:41]
# Out:
# ['LEVENT MOTORS-2017 MERCEDES E 300 COUPE COMMAND+HAYALET NVG VKM.',
#  'Önceki',
#  'Sonraki',
#  '1/25',
#  'Önceki',
#  'Sonraki',
#  '960.000 TL',
#  'İSTANBUL / BEŞİKTAŞ / NİSBETİYE MAHALLESİ',
#  'İlan No:',
#  '17188504',
#  'İlan Tarihi:',
#  '21 Mart 2021',
#  'Marka:',
#  'Mercedes - Benz',
#  'Seri:',
#  'E',
#  'Model:',
#  '300 AMG',
#  'Yıl:',
#  '2017',
#  'Yakıt Tipi:',
#  'Benzin',
#  'Vites Tipi:',
#  'Otomatik',
#  'Motor Hacmi:',
#  '1991 cc',
#  'Motor Gücü:',
#  '245 hp',
#  'Kilometre:',
#  '32.000 km',
#  'Şasi Numarası:',
#  '-****************',
#  'Plaka:',
#  '-',
#  'Boya-değişen:',
#  'Tamamı orjinal',
#  'Takasa Uygun:',
#  'Takasa Uygun',
#  'Kimden:',
#  'Galeriden',
#  'Karşılaştır']

# %%
import pandas as pd
lst = [   [ contlist[9],contlist[13],contlist[17],contlist[15],contlist[19],contlist[29],contlist[6],contlist[11],contlist[23],contlist[21],contlist[25],contlist[27],contlist[39],contlist[0],contlist[7]  ]   ] 
    
df_simple = pd.DataFrame(lst,columns=['advertisement_number','brand','model','series','year','km', 'price','advertisement_date','gear','fuel','engine_capacity','engine_power','from','title','city']) 
df_simple
# Out:
#   advertisement_number            brand    model series  year         km  \
# 0             17188504  Mercedes - Benz  300 AMG      E  2017  32.000 km
#
#         price advertisement_date      gear    fuel engine_capacity  \
# 0  960.000 TL       21 Mart 2021  Otomatik  Benzin         1991 cc
#
#   engine_power       from                                              title  \
# 0       245 hp  Galeriden  LEVENT MOTORS-2017 MERCEDES E 300 COUPE COMMAN...
#
#                                         city
# 0  İSTANBUL / BEŞİKTAŞ / NİSBETİYE MAHALLESİ

# %%
empty_list=[]
df = pd.DataFrame(empty_list,columns=['advertisement_number','brand','model','series','year','km', 'price','advertisement_date','gear','fuel','engine_capacity','engine_power','from','title','city']) 
df
# Out:
# Empty DataFrame
# Columns: [advertisement_number, brand, model, series, year, km, price, advertisement_date, gear, fuel, engine_capacity, engine_power, from, title, city]
# Index: []

# %%
driver_path='C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe'
browser=webdriver.Chrome(driver_path)
url='https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-e'
browser.get(url)

for i in range(20):
   //*[@id="park_or_compare"]/table/tbody/tr[2]
   //*[@id="park_or_compare"]/table/tbody/tr[3]

# %%
driver_path='C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe'
browser=webdriver.Chrome(driver_path)

url='https://www.araba.com/ilan/lansman-rengi-2016-gla-180-amg-4244870'

browser.get(url)

content=browser.find_elements_by_xpath('/html/body/div[1]/div[7]/div[2]/div[3]')

#content
contlist=[]
for i in content:
    a=i.text
    contlist=a.split("\n")
contlist[:]
# Out:
# ['GLA 180 CDI AMG',
#  'Favorilerime Ekle',
#  'Yazdır',
#  'LANSMAN RENGI 2016 GLA 180 AMG',
#  'Fotoğrafları Büyüt',
#  '1/12',
#  '419.750 TL',
#  '8.120 TL den başlayan taksitlerle »',
#  'ARABA DEĞERİ HESAPLA',
#  'Kahramanmaraş',
#  '/ Pazarcık / Merkez',
#  'İlan No:',
#  '#4244870',
#  'İlan Tarihi:',
#  '22/03/2021',
#  'Marka:',
#  'Mercedes',
#  'Model:',
#  'GLA',
#  'Varyant:',
#  '180 CDI AMG',
#  'Model Yılı:',
#  '2016',
#  'Kilometre:',
#  '51.000',
#  'Yakıt Türü:',
#  'Dizel',
#  'Vites Tipi:',
#  'Yarı Otomatik Vites',
#  'Motor Hacmi:',
#  '1301-1600 cc',
#  'Motor Gücü:',
#  '101-125 BG',
#  'Kimden:',
#  'Galeriden',
#  'Boyalı - Değişen',
#  'Teknik Özellikler',
#  'Açıklama',
#  'Orjinal',
#  'Boyalı',
#  'Lokal Boyalı',
#  'Değişen',
#  '',
#  '',
#  'Araba.com Kredi',
#  'Vade (Ay)',
#  '12',
#  '24',
#  '36',
#  '48',
#  '60',
#  'AYLIK TAKSİT:',
#  '8.120 TL',
#  'Krediye Başvur',
#  'Plaka No Girin',
#  'Hasar Sorgula',
#  'Koçi̇n Otomoti̇v',
#  '(2.4)',
#  'Değerlendir',
#  'Tüm İlanları »',
#  'Ara',
#  'Ara',
#  'İlan Sahibine Sor',
#  'İlan ile İlgili Şikayetim Var']

# %%
import pandas as pd
lst = [   [ contlist[12],contlist[16],contlist[18],contlist[20],contlist[22],contlist[24],contlist[6],contlist[14],contlist[28],contlist[26],contlist[30],contlist[32],contlist[34],contlist[9],contlist[3]  ]   ] 
    
df_simple = pd.DataFrame(lst,columns=['advertisement_number','brand','series','version','year','km', 'price','advertisement_date','gear','fuel','engine_capacity','engine_power','from','city','title']) 
df_simple
# Out:
#   advertisement_number     brand series      version  year      km  \
# 0             #4244870  Mercedes    GLA  180 CDI AMG  2016  51.000
#
#         price advertisement_date                 gear   fuel engine_capacity  \
# 0  419.750 TL         22/03/2021  Yarı Otomatik Vites  Dizel    1301-1600 cc
#
#   engine_power       from           city                           title
# 0   101-125 BG  Galeriden  Kahramanmaraş  LANSMAN RENGI 2016 GLA 180 AMG

# %%
empty_list=[]
df = pd.DataFrame(empty_list,columns=['advertisement_number','brand','series','version','year','km', 'price','advertisement_date','gear','fuel','engine_capacity','engine_power','from','city','title']) 
df
# Out:
# Empty DataFrame
# Columns: [advertisement_number, brand, series, version, year, km, price, advertisement_date, gear, fuel, engine_capacity, engine_power, from, city, title]
# Index: []

# %%
driver_path='C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe'
browser=webdriver.Chrome(driver_path)
url='https://www.araba.com/otomobil/mercedes-e-serisi'
browser.get(url)


for i in range(2,8):
    if(i==6 or i==11):
        continue
    box_ = browser.find_element_by_xpath('//*[@id="park_or_compare"]/table/tbody/tr['+str(i)+ ']')
    box_.click()
    
    content=browser.find_elements_by_xpath('/html/body/div[1]/div[7]/div[2]/div[3]')

    #content
    contlist=[]
    for i in content:
        a=i.text
        contlist=a.split("\n")
    contlist[:]
    #to_append = [5, 6]
    #df.append(pd.DataFrame(contlist))
    
    browser.execute_script("window.history.go(-1)")
    for j in contlist:
        print(j)
    print('-------------------------------------------------')
# Out:
# E Serisi E 250 BlueTEC
# Favorilerime Ekle
# Yazdır
# MERCEDES BENZ E 250 ELITE SIFIR AYARINDA BOYASIZ
# Önceki İlan
# Sonraki İlan
# Fotoğrafları Büyüt
# 1/8
# 525.000 TL
# 10.157 TL den başlayan taksitlerle »
# ARABA DEĞERİ HESAPLA
# Ankara
# / Çankaya / Çayyolu
# İlan No:
# #2798325
# İlan Tarihi:
# 22/03/2021
# Marka:
# Mercedes
# Model:
# E Serisi
# Varyant:
# E 250 BlueTEC
# Model Yılı:
# 2015
# Kilometre:
# 150.000
# Yakıt Türü:
# Benzin
# Vites Tipi:
# Otomatik Vites
# Motor Hacmi:
# 1801-2000 cc
# Motor Gücü:
# 126-150 BG
# Kimden:
# Galeriden
# Boyalı - Değişen
# Teknik Özellikler
# Açıklama
# Orjinal
# Boyalı
# Lokal Boyalı
# Değişen
#
#
# Araba.com Kredi
# Vade (Ay)
# 12
# 24
# 36
# 48
# 60
# AYLIK TAKSİT:
# 10.157 TL
# Krediye Başvur
# Plaka No Girin
# Hasar Sorgula
# Nuh Bayram
# (1.4)
# Değerlendir
# Tüm İlanları »
# Ara
# Ara
# İlan Sahibine Sor
# İlan ile İlgili Şikayetim Var
# -------------------------------------------------
# E Serisi E 180 Elite
# Favorilerime Ekle
# Yazdır
# 2013 MERCEDES E180 ELİTE-80.000 KM- Mercedes - Benz E Serisi E 180 Elite
# Önceki İlan
# Sonraki İlan
# Fotoğrafları Büyüt
# 1/25
# 389.000 TL
# 7.526 TL den başlayan taksitlerle »
# ARABA DEĞERİ HESAPLA
# Ankara
# / Çankaya / Birlik
# İlan No:
# #4324911
# İlan Tarihi:
# 21/03/2021
# Marka:
# Mercedes
# Model:
# E Serisi
# Varyant:
# E 180 Elite
# Model Yılı:
# 2013
# Kilometre:
# 80.200
# Yakıt Türü:
# Benzin
# Vites Tipi:
# Yarı Otomatik Vites
# Motor Hacmi:
# 1301-1600 cc
# Motor Gücü:
# Bilmiyorum
# Kimden:
# Galeriden
# Boyalı - Değişen
# Teknik Özellikler
# Açıklama
# Orjinal
# Boyalı
# Lokal Boyalı
# Değişen
#
#
#
#
#
#
# Araba.com Kredi
# Vade (Ay)
# 12
# 24
# 36
# 48
# 60
# AYLIK TAKSİT:
# 7.526 TL
# Krediye Başvur
# Plaka No Girin
# Hasar Sorgula
# NEVA KURUMSAL
# (4.3)
# Değerlendir
# Tüm İlanları »
# Ara
# İlan Sahibine Sor
# İlan ile İlgili Şikayetim Var
# -------------------------------------------------
# E Serisi E 250 CDI BlueEfficiency Avantgarde
# Favorilerime Ekle
# Yazdır
# KARAELMAS DAN E250 CDI ÇİFT HAREKET HAFIZA CAM TAVAN TABA DERİ Mercedes - Benz E Serisi E 250 CDI BlueEfficiency Avantgarde
# Önceki İlan
# Sonraki İlan
# Fotoğrafları Büyüt
# 1/25
# 310.000 TL
# 5.997 TL den başlayan taksitlerle »
# ARABA DEĞERİ HESAPLA
# Kilis
# / Merkez / Merkez
# İlan No:
# #4590792
# İlan Tarihi:
# 21/03/2021
# Marka:
# Mercedes
# Model:
# E Serisi
# Varyant:
# E 250 CDI BlueEfficiency Avantgarde
# Model Yılı:
# 2010
# Kilometre:
# 302.000
# Yakıt Türü:
# Dizel
# Vites Tipi:
# Yarı Otomatik Vites
# Motor Hacmi:
# 2001-2500 cc
# Motor Gücü:
# Bilmiyorum
# Kimden:
# Galeriden
# Boyalı - Değişen
# Teknik Özellikler
# Açıklama
# Orjinal
# Boyalı
# Lokal Boyalı
# Değişen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Araba.com Kredi
# Vade (Ay)
# 12
# 24
# 36
# 48
# 60
# AYLIK TAKSİT:
# 5.997 TL
# Krediye Başvur
# Plaka No Girin
# Hasar Sorgula
# Karaelmas Auto
# (3.3)
# Değerlendir
# Tüm İlanları »
# Ara
# İlan Sahibine Sor
# İlan ile İlgili Şikayetim Var
# -------------------------------------------------
# E Serisi E 220 CDI Elegance
# Favorilerime Ekle
# Yazdır
# GARAC 79 dan 2005 W 211 E 220 CDI ELEGANCE OTOMATK 237.000 KM DE Mercedes - Benz E Serisi E 220 CDI Elegance
# Önceki İlan
# Sonraki İlan
# Fotoğrafları Büyüt
# 1/25
# 215.000 TL
# 4.159 TL den başlayan taksitlerle »
# ARABA DEĞERİ HESAPLA
# Kilis
# / Merkez / Merkez
# İlan No:
# #2743421
# İlan Tarihi:
# 21/03/2021
# Marka:
# Mercedes
# Model:
# E Serisi
# Varyant:
# E 220 CDI Elegance
# Model Yılı:
# 2005
# Kilometre:
# 237.000
# Yakıt Türü:
# Dizel
# Vites Tipi:
# Yarı Otomatik Vites
# Motor Hacmi:
# 2001-2500 cc
# Motor Gücü:
# Bilmiyorum
# Kimden:
# Galeriden
# Boyalı - Değişen
# Teknik Özellikler
# Açıklama
# Orjinal
# Boyalı
# Lokal Boyalı
# Değişen
#
#
#
#
#
# Araba.com Kredi
# Vade (Ay)
# 12
# 24
# 36
# 48
# 60
# AYLIK TAKSİT:
# 4.159 TL
# Krediye Başvur
# Plaka No Girin
# Hasar Sorgula
# Garac 79
# (4.0)
# Değerlendir
# Tüm İlanları »
# Ara
# İlan Sahibine Sor
# İlan ile İlgili Şikayetim Var
# -------------------------------------------------
# E Serisi E 180 Exclusive
# Favorilerime Ekle
# Yazdır
# STELLA MOTORS 2018 MERCEDES BENZ E180 EXCLUSİVE Mercedes - Benz E Serisi E 180 Exclusive
# Önceki İlan
# Sonraki İlan
# Fotoğrafları Büyüt
# 1/18
# 695.000 TL
# 13.445 TL den başlayan taksitlerle »
# ARABA DEĞERİ HESAPLA
# İstanbul
# / Kadıköy / Göztepe
# İlan No:
# #1184828
# İlan Tarihi:
# 21/03/2021
# Marka:
# Mercedes
# Model:
# E Serisi
# Varyant:
# E 180 Exclusive
# Model Yılı:
# 2018
# Kilometre:
# 33.500
# Yakıt Türü:
# Benzin
# Vites Tipi:
# Otomatik Vites
# Motor Hacmi:
# 1301-1600 cc
# Motor Gücü:
# Bilmiyorum
# Kimden:
# Galeriden
# Boyalı - Değişen
# Teknik Özellikler
# Açıklama
# Orjinal
# Boyalı
# Lokal Boyalı
# Değişen
# Araba.com Kredi
# Vade (Ay)
# 12
# 24
# 36
# 48
# 60
# AYLIK TAKSİT:
# 13.445 TL
# Krediye Başvur
# Plaka No Girin
# Hasar Sorgula
# Stella Motors
# (3.9)
# Değerlendir
# Tüm İlanları »
# Ara
# Ara
# İlan Sahibine Sor
# İlan ile İlgili Şikayetim Var
# -------------------------------------------------
